# %% [markdown]
# ## Comparison between CAC40, DAX30 and DOW JONES index (total return)
# Criteria : # of companies
# According to the Buy-and-hold theory
#
# - Import data to csv files
# - Select and manage datas
# - Build Kit to start our analysis
#
# -

# %%
import risk_return_tool as rrt

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
idx_ret = rrt.index_return()
idx_ret
# Out:
#            CAC TR       DAX     DJIA TR
# date
# 2007-03   9599.01   6917.03  20098.4492
# 2007-04  10168.10   7408.87  21277.1992
# 2007-05  10594.30   7883.04  22261.0996
# 2007-06  10563.70   8007.32  21929.8105
# 2007-07  10039.50   7584.14  21633.8809
# ...           ...       ...         ...
# 2019-12  16242.10  13249.01  64505.4805
# 2020-01  15801.32  12996.28  63933.6797
# 2020-02  14450.31  11890.35  57697.3086
# 2020-03  11994.80   9928.19  49840.3086
# 2020-04  12482.89  10840.91  55431.8086
#
# [158 rows x 3 columns]

# %%
idx_ret = idx_ret.pct_change()
idx_ret
# Out:
#            CAC TR       DAX   DJIA TR
# date
# 2007-03       NaN       NaN       NaN
# 2007-04  0.059286  0.071106  0.058649
# 2007-05  0.041915  0.064000  0.046242
# 2007-06 -0.002888  0.015765 -0.014882
# 2007-07 -0.049623 -0.052849 -0.013494
# ...           ...       ...       ...
# 2019-12  0.013327  0.000351  0.018668
# 2020-01 -0.027138 -0.019075 -0.008864
# 2020-02 -0.085500 -0.085096 -0.097544
# 2020-03 -0.169928 -0.165021 -0.136176
# 2020-04  0.040692  0.091932  0.112188
#
# [158 rows x 3 columns]

# %%
idx_ret.plot()
